# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal, constants
# %matplotlib inline

# %%
globals().update(np.load("/tmp/screen.npz"))

# %%
t = np.arange(y1.shape[0])*x[0] + x[1]
y = np.c_[y1, y2].T
plt.plot(t[:100], y[:, :100].T);

# %%
z = signal.decimate(y*np.exp(1j*2*np.pi*50e6*t), q=100, ftype="fir", zero_phase=True)[:, 100:]
z = signal.decimate(z, q=100, ftype="fir", zero_phase=True)[:, 100:]
plt.plot(np.angle(z[0]*z[1].conj()))
np.angle(np.mean(z[0]*z[1].conj()))
# Out:
# 2.3951481344710026
